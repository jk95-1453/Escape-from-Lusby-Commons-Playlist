# %% [markdown]
# <a href="https://colab.research.google.com/github/jk95-1453/Escape-from-Lusby-Commons-Playlist/blob/main/Escape_From_Lusby_Commons_Songs_List.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
escape_from_lusby_commons_songs = ["The Green Pill", "Breaking Point", "Khaybar", "The Escape," "Devil with a Halo," "I Have No Enemies", "Leap of Faith", "Tranformation Complete", "Deal with the Devil", "Another World", "Desert Safari", "Bittersweet Homecoming," "Halo of the Night"]

# %%
print(escape_from_lusby_commons_songs)
# Out:
# ['The Green Pill', 'Breaking Point', 'Khaybar', 'The Escape,Devil with a Halo,I Have No Enemies', 'Leap of Faith', 'Tranformation Complete', 'Deal with the Devil', 'Another World', 'Desert Safari', 'Bittersweet Homecoming,Halo of the Night']

# %%
track_length = ["3:25", "3:01", "2:21", "2:09"]

# %%
print(track_length)
# Out:
# ['3:25', '3:01', '2:21', '2:09']
